# %%
#Imports
import numpy as np
import pandas as pd
from scipy import linalg
import pdb
import sys
import matplotlib.pyplot as plt
sys.path.append(r'C:\Users\julie\OneDrive - polymtl.ca\Phd_CIRAIG\4.Coeur\Codes\PRISMAL_project')
from PRISMAL import Prismal

# %%
#Creation of the different scenarios

PRISMAL1_19 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL1','MS19', 'prod_geo_bl')
PRISMAL1_26 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL1','MS26', 'prod_geo_bl')
PRISMAL1_34 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL1','MS34', 'prod_geo_bl')
PRISMAL1_45 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL1','MS45', 'prod_geo_bl')
PRISMAL1_bl = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL1','Baseline', 'prod_geo_bl')

PRISMAL2_19 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL2','MS19', 'prod_geo_bl')
PRISMAL2_26 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL2','MS26', 'prod_geo_bl')
PRISMAL2_34 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL2','MS34', 'prod_geo_bl')
PRISMAL2_45 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL2','MS45', 'prod_geo_bl')
PRISMAL2_60 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL2','MS60', 'prod_geo_bl')
PRISMAL2_bl = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL2','Baseline', 'prod_geo_bl')

PRISMAL3_34 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL3','MS34', 'prod_geo_bl')
PRISMAL3_45 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL3','MS45','prod_geo_bl')
PRISMAL3_60 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL3','MS60', 'prod_geo_bl')
PRISMAL3_bl = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL3','Baseline', 'prod_geo_bl')

PRISMAL4_26 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL4','MS26', 'prod_geo_bl')
PRISMAL4_34 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL4','MS34', 'prod_geo_bl')
PRISMAL4_45 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL4','MS45', 'prod_geo_bl')
PRISMAL4_bl = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL4','Baseline', 'prod_geo_bl')

PRISMAL5_19 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL5','MS19', 'prod_geo_bl')
PRISMAL5_26 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL5','MS26', 'prod_geo_bl')
PRISMAL5_34 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL5','MS34', 'prod_geo_bl')
PRISMAL5_45 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL5','MS45', 'prod_geo_bl')
PRISMAL5_60 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL5','MS60', 'prod_geo_bl')
PRISMAL5_bl = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL5','Baseline', 'prod_geo_bl')

# %%
#Solving every scenarios

PRISMAL1_19.solve()
PRISMAL1_26.solve()
PRISMAL1_34.solve()
PRISMAL1_45.solve()
PRISMAL1_bl.solve()

PRISMAL2_19.solve()
PRISMAL2_26.solve()
PRISMAL2_34.solve()
PRISMAL2_45.solve()
PRISMAL2_60.solve()
PRISMAL2_bl.solve()

PRISMAL3_34.solve()
PRISMAL3_45.solve()
PRISMAL3_60.solve()
PRISMAL3_bl.solve()

PRISMAL4_26.solve()
PRISMAL4_34.solve()
PRISMAL4_45.solve()
PRISMAL4_bl.solve()

PRISMAL5_19.solve()
PRISMAL5_26.solve()
PRISMAL5_34.solve()
PRISMAL5_45.solve()
PRISMAL5_60.solve()
PRISMAL5_bl.solve()

# %%
#Agreagtion of different PRISMAL into a result table
prismal1_bl = pd.concat([PRISMAL1_bl.i_al_prod], keys=['msbl'])
prismal1_bl = pd.concat([prismal1_bl], keys=['PRISMAL1'])
prismal1_19 = pd.concat([PRISMAL1_19.i_al_prod], keys=['ms19'])
prismal1_19 = pd.concat([prismal1_19], keys=['PRISMAL1'])
prismal1_26 = pd.concat([PRISMAL1_26.i_al_prod], keys=['ms26'])
prismal1_26 = pd.concat([prismal1_26], keys=['PRISMAL1'])
prismal1_34 = pd.concat([PRISMAL1_34.i_al_prod], keys=['ms34'])
prismal1_34 = pd.concat([prismal1_34], keys=['PRISMAL1'])
prismal1_45 = pd.concat([PRISMAL1_45.i_al_prod], keys=['ms45'])
prismal1_45 = pd.concat([prismal1_45], keys=['PRISMAL1'])
prismal1 = pd.concat([prismal1_19, prismal1_26, prismal1_34, prismal1_45, prismal1_bl])

prismal2_bl = pd.concat([PRISMAL2_bl.i_al_prod], keys=['msbl'])
prismal2_bl = pd.concat([prismal2_bl], keys=['PRISMAL2'])
prismal2_19 = pd.concat([PRISMAL2_19.i_al_prod], keys=['ms19'])
prismal2_19 = pd.concat([prismal2_19], keys=['PRISMAL2'])
prismal2_26 = pd.concat([PRISMAL2_26.i_al_prod], keys=['ms26'])
prismal2_26 = pd.concat([prismal2_26], keys=['PRISMAL2'])
prismal2_34 = pd.concat([PRISMAL2_34.i_al_prod], keys=['ms34'])
prismal2_34 = pd.concat([prismal2_34], keys=['PRISMAL2'])
prismal2_45 = pd.concat([PRISMAL2_45.i_al_prod], keys=['ms45'])
prismal2_45 = pd.concat([prismal2_45], keys=['PRISMAL2'])
prismal2_60 = pd.concat([PRISMAL2_60.i_al_prod], keys=['ms60'])
prismal2_60 = pd.concat([prismal2_60], keys=['PRISMAL2'])
prismal2 = pd.concat([prismal2_19, prismal2_26, prismal2_34, prismal2_45, prismal2_60, prismal2_bl])

prismal3_bl = pd.concat([PRISMAL3_bl.i_al_prod], keys=['msbl'])
prismal3_bl = pd.concat([prismal3_bl], keys=['PRISMAL3'])
prismal3_34 = pd.concat([PRISMAL3_34.i_al_prod], keys=['ms34'])
prismal3_34 = pd.concat([prismal3_34], keys=['PRISMAL3'])
prismal3_45 = pd.concat([PRISMAL3_45.i_al_prod], keys=['ms45'])
prismal3_45 = pd.concat([prismal3_45], keys=['PRISMAL3'])
prismal3_60 = pd.concat([PRISMAL3_60.i_al_prod], keys=['ms60'])
prismal3_60 = pd.concat([prismal3_60], keys=['PRISMAL3'])
prismal3 = pd.concat([prismal3_34, prismal3_45, prismal3_60, prismal3_bl])

prismal4_bl = pd.concat([PRISMAL4_bl.i_al_prod], keys=['msbl'])
prismal4_bl = pd.concat([prismal4_bl], keys=['PRISMAL4'])
prismal4_26 = pd.concat([PRISMAL4_26.i_al_prod], keys=['ms26'])
prismal4_26 = pd.concat([prismal4_26], keys=['PRISMAL4'])
prismal4_34 = pd.concat([PRISMAL4_34.i_al_prod], keys=['ms34'])
prismal4_34 = pd.concat([prismal4_34], keys=['PRISMAL4'])
prismal4_45 = pd.concat([PRISMAL4_45.i_al_prod], keys=['ms45'])
prismal4_45 = pd.concat([prismal4_45], keys=['PRISMAL4'])
#Adjeustment of PRIMSAL4 2005
prismal4_bl.loc(axis=1)[2005] = prismal4_bl.loc(axis=1)[2010].values
prismal4_26.loc(axis=1)[2005] = prismal4_26.loc(axis=1)[2010].values
prismal4_34.loc(axis=1)[2005] = prismal4_34.loc(axis=1)[2010].values
prismal4_45.loc(axis=1)[2005] = prismal4_45.loc(axis=1)[2010].values
prismal4 = pd.concat([prismal4_26, prismal4_34, prismal4_45, prismal4_bl])

prismal5_bl = pd.concat([PRISMAL5_bl.i_al_prod], keys=['msbl'])
prismal5_bl = pd.concat([prismal5_bl], keys=['PRISMAL5'])
prismal5_19 = pd.concat([PRISMAL5_19.i_al_prod], keys=['ms19'])
prismal5_19 = pd.concat([prismal5_19], keys=['PRISMAL5'])
prismal5_26 = pd.concat([PRISMAL5_26.i_al_prod], keys=['ms26'])
prismal5_26 = pd.concat([prismal5_26], keys=['PRISMAL5'])
prismal5_34 = pd.concat([PRISMAL5_34.i_al_prod], keys=['ms34'])
prismal5_34 = pd.concat([prismal5_34], keys=['PRISMAL5'])
prismal5_45 = pd.concat([PRISMAL5_45.i_al_prod], keys=['ms45'])
prismal5_45 = pd.concat([prismal5_45], keys=['PRISMAL5'])
prismal5_60 = pd.concat([PRISMAL5_60.i_al_prod], keys=['ms60'])
prismal5_60 = pd.concat([prismal5_60], keys=['PRISMAL5'])
prismal5 = pd.concat([prismal5_19, prismal5_26, prismal5_34, prismal5_45, prismal5_60, prismal5_bl])

prismal_all = pd.concat([prismal1, prismal2, prismal3, prismal4, prismal5], axis=0)
prismal_all.index.names = ['PRISMAL','MS','Stage', 'Regions', 'Impacts']
prismal_all.columns.names = ['Year']

# %%
#Agreagtion of different improvments into a table

prismal1_imp_bl = pd.concat([PRISMAL1_bl.i_improvments], keys=['msbl'])
prismal1_imp_bl = pd.concat([prismal1_imp_bl], keys=['PRISMAL1'])
prismal1_imp_19 = pd.concat([PRISMAL1_19.i_improvments], keys=['ms19'])
prismal1_imp_19 = pd.concat([prismal1_imp_19], keys=['PRISMAL1'])
prismal1_imp_26 = pd.concat([PRISMAL1_26.i_improvments], keys=['ms26'])
prismal1_imp_26 = pd.concat([prismal1_imp_26], keys=['PRISMAL1'])
prismal1_imp_34 = pd.concat([PRISMAL1_34.i_improvments], keys=['ms34'])
prismal1_imp_34 = pd.concat([prismal1_imp_34], keys=['PRISMAL1'])
prismal1_imp_45 = pd.concat([PRISMAL1_45.i_improvments], keys=['ms45'])
prismal1_imp_45 = pd.concat([prismal1_imp_45], keys=['PRISMAL1'])
prismal1_imp = pd.concat([prismal1_imp_19, prismal1_imp_26, prismal1_imp_34, prismal1_imp_45, prismal1_imp_bl])

prismal2_imp_bl = pd.concat([PRISMAL2_bl.i_improvments], keys=['msbl'])
prismal2_imp_bl = pd.concat([prismal2_imp_bl], keys=['PRISMAL2'])
prismal2_imp_19 = pd.concat([PRISMAL2_19.i_improvments], keys=['ms19'])
prismal2_imp_19 = pd.concat([prismal2_imp_19], keys=['PRISMAL2'])
prismal2_imp_26 = pd.concat([PRISMAL2_26.i_improvments], keys=['ms26'])
prismal2_imp_26 = pd.concat([prismal2_imp_26], keys=['PRISMAL2'])
prismal2_imp_34 = pd.concat([PRISMAL2_34.i_improvments], keys=['ms34'])
prismal2_imp_34 = pd.concat([prismal2_imp_34], keys=['PRISMAL2'])
prismal2_imp_45 = pd.concat([PRISMAL2_45.i_improvments], keys=['ms45'])
prismal2_imp_45 = pd.concat([prismal2_imp_45], keys=['PRISMAL2'])
prismal2_imp_60 = pd.concat([PRISMAL2_60.i_improvments], keys=['ms60'])
prismal2_imp_60 = pd.concat([prismal2_imp_60], keys=['PRISMAL2'])
prismal2_imp = pd.concat([prismal2_imp_19, prismal2_imp_26, prismal2_imp_34, prismal2_imp_45, prismal2_imp_60, prismal2_imp_bl])

prismal3_imp_bl = pd.concat([PRISMAL3_bl.i_improvments], keys=['msbl'])
prismal3_imp_bl = pd.concat([prismal3_imp_bl], keys=['PRISMAL3'])
prismal3_imp_34 = pd.concat([PRISMAL3_34.i_improvments], keys=['ms34'])
prismal3_imp_34 = pd.concat([prismal3_imp_34], keys=['PRISMAL3'])
prismal3_imp_45 = pd.concat([PRISMAL3_45.i_improvments], keys=['ms45'])
prismal3_imp_45 = pd.concat([prismal3_imp_45], keys=['PRISMAL3'])
prismal3_imp_60 = pd.concat([PRISMAL3_60.i_improvments], keys=['ms60'])
prismal3_imp_60 = pd.concat([prismal3_imp_60], keys=['PRISMAL3'])
prismal3_imp = pd.concat([prismal3_imp_34, prismal3_imp_45, prismal3_imp_60, prismal3_imp_bl])

prismal4_imp_bl = pd.concat([PRISMAL4_bl.i_improvments], keys=['msbl'])
prismal4_imp_bl = pd.concat([prismal4_imp_bl], keys=['PRISMAL4'])
prismal4_imp_26 = pd.concat([PRISMAL4_26.i_improvments], keys=['ms26'])
prismal4_imp_26 = pd.concat([prismal4_imp_26], keys=['PRISMAL4'])
prismal4_imp_34 = pd.concat([PRISMAL4_34.i_improvments], keys=['ms34'])
prismal4_imp_34 = pd.concat([prismal4_imp_34], keys=['PRISMAL4'])
prismal4_imp_45 = pd.concat([PRISMAL4_45.i_improvments], keys=['ms45'])
prismal4_imp_45 = pd.concat([prismal4_imp_45], keys=['PRISMAL4'])
prismal4_imp = pd.concat([prismal4_imp_26, prismal4_imp_34, prismal4_imp_45, prismal4_imp_bl])

prismal5_imp_bl = pd.concat([PRISMAL5_bl.i_improvments], keys=['msbl'])
prismal5_imp_bl = pd.concat([prismal5_imp_bl], keys=['PRISMAL5'])
prismal5_imp_19 = pd.concat([PRISMAL5_19.i_improvments], keys=['ms19'])
prismal5_imp_19 = pd.concat([prismal5_imp_19], keys=['PRISMAL5'])
prismal5_imp_26 = pd.concat([PRISMAL5_26.i_improvments], keys=['ms26'])
prismal5_imp_26 = pd.concat([prismal5_imp_26], keys=['PRISMAL5'])
prismal5_imp_34 = pd.concat([PRISMAL5_34.i_improvments], keys=['ms34'])
prismal5_imp_34 = pd.concat([prismal5_imp_34], keys=['PRISMAL5'])
prismal5_imp_45 = pd.concat([PRISMAL5_45.i_improvments], keys=['ms45'])
prismal5_imp_45 = pd.concat([prismal5_imp_45], keys=['PRISMAL5'])
prismal5_imp_60 = pd.concat([PRISMAL5_60.i_improvments], keys=['ms60'])
prismal5_imp_60 = pd.concat([prismal5_imp_60], keys=['PRISMAL5'])
prismal5_imp = pd.concat([prismal5_imp_26, prismal5_imp_34, prismal5_imp_45, prismal5_imp_60, prismal5_imp_bl])

prismal_imp_all = pd.concat([prismal1_imp, prismal2_imp, prismal3_imp, prismal4_imp, prismal5_imp], axis=0)
prismal_imp_all.index.names = ['PRISMAL','MS','Improvments', 'Regions', 'Impacts']

# %% [markdown]
# ## Total impacts

# %%
#Scale up of relative impacts to total impacts
prismal_total = prismal_all.mul(PRISMAL1_bl.production).loc(axis=1)[[2005, 2010, 2020, 2030, 2040, 2050]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aa004146ffb3> in <module>()
#       1 #Scale up of relative impacts to total impacts
# ----> 2 prismal_total = prismal_all.mul(PRISMAL1_bl.production).loc(axis=1)[[2005, 2010, 2020, 2030, 2040, 2050]]
#
# NameError: name 'prismal_all' is not defined

# %% [markdown]
# # Graph

# %% [markdown]
# ## PRISMAL - Impacts categories

# %%
#2050 time horizon
#Global average impact for every PRISMAL scenarios and related mitigations scenarios
region = 'GLO'
impact = 'GHG'

#Unit for y axis
unit=''
if impact=='GHG':
    unit='GHG [kg CO2 eq / kg Al]'
    
if impact=='HH':
    unit='HH [DALY / kg Al]'
    
if impact=='EQ':
    unit='EQ [PDF·m2·yr/m3 / kg Al]'

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1, 1, 1)
x = [2005,2010,2020,2030,2040,2050]

#PRISMAL1
y1_1 = prismal_all.loc(axis=0)['PRISMAL1','msbl',:,region, impact].loc(axis=1)[x].sum()
y1_2 = prismal_all.loc(axis=0)['PRISMAL1','ms19',:,region, impact].loc(axis=1)[x].sum()
ax.fill_between(x, y1_1, y1_2, facecolor='green', alpha=0.1)
y1_1.plot(color='green', linewidth=4)
y1_2.plot(color='green', ls='--', alpha=1)
prismal_all.loc(axis=0)['PRISMAL1','ms19',:,region, impact].loc(axis=1)[2050].sum()
y1_19 = prismal_all.loc(axis=0)['PRISMAL1','ms19',:,region, impact].loc(axis=1)[2050].sum()
plt.scatter(2050.75, y1_19, marker='*', color='green')
y1_26 = prismal_all.loc(axis=0)['PRISMAL1','ms26',:,region, impact].loc(axis=1)[2050].sum()
plt.scatter(2050.75, y1_26, marker='+',color='green')

#PRISMAL2
y2_1 = prismal_all.loc(axis=0)['PRISMAL2','msbl',:,region, impact].loc(axis=1)[x].sum()
y2_2 = prismal_all.loc(axis=0)['PRISMAL2','ms19',:,region, impact].loc(axis=1)[x].sum()
ax.fill_between(x, y2_1, y2_2, facecolor='blue', alpha=0.1)
y2_1.plot(color='blue', linewidth=4)
y2_2.plot(color='blue', ls='--', alpha=1)
y2_19 = prismal_all.loc(axis=0)['PRISMAL2','ms19',:,region, impact].loc(axis=1)[2050].sum()
plt.scatter(2051.5, y2_19, marker='*', color='blue')
y2_26 = prismal_all.loc(axis=0)['PRISMAL2','ms26',:,region, impact].loc(axis=1)[2050].sum()
plt.scatter(2051.5, y2_26, marker='+',color='blue')


#PRISMAL3
y3_1 = prismal_all.loc(axis=0)['PRISMAL3','msbl',:,region, impact].loc(axis=1)[x].sum()
#y3_2 = prismal_all.loc(axis=0)['PRISMAL3','ms34',:,region, impact].loc(axis=1)[x].loc(axis=1)[x].sum()
#ax.fill_between(x, y3_1, y3_2, facecolor='red', alpha=0.1)
y3_1.plot(color='red', linewidth=4)
#y3_2.plot(color='red', ls='--', alpha=1)
#lin3 = pd.Series([y3_2[2050],y3_1[2050]], [2052.25, 2052.25])
#lin3.plot(color='red')

#PRISMAL4
y4_1 = prismal_all.loc(axis=0)['PRISMAL4','msbl',:,region, impact].loc(axis=1)[x].sum()
y4_2 = prismal_all.loc(axis=0)['PRISMAL4','ms26',:,region, impact].loc(axis=1)[x].sum()
ax.fill_between(x, y4_1, y4_2, facecolor='orange', alpha=0.1)
y4_1.plot(color='orange', linewidth=4)
y4_2.plot(color='orange', ls='--', alpha=1)
y4_26 = prismal_all.loc(axis=0)['PRISMAL4','ms26',:,region, impact].loc(axis=1)[2050].sum()
plt.scatter(2052.25, y4_26, marker='+',color='orange')

#PRISMAL5
y5_1 = prismal_all.loc(axis=0)['PRISMAL5','msbl',:,region, impact].loc(axis=1)[x].sum()
y5_2 = prismal_all.loc(axis=0)['PRISMAL5','ms19',:,region, impact].loc(axis=1)[x].sum()
ax.fill_between(x, y5_1, y5_2, facecolor='purple', alpha=0.1, edgecolor='orange')
y5_1.plot(color='purple', linewidth=4)
y5_2.plot(color='purple', ls='--', alpha=1)
y5_19 = prismal_all.loc(axis=0)['PRISMAL5','ms19',:,region, impact].loc(axis=1)[2050].sum()
y5_26 = prismal_all.loc(axis=0)['PRISMAL5','ms26',:,region, impact].loc(axis=1)[2050].sum()
plt.scatter(2053, y5_19, marker='*',color='purple')
plt.scatter(2053, y5_26, marker='+',color='purple')


#Legend of Migigation scenario
ms19 = plt.scatter(0, y1_19, marker='*',color='k')
ms26 = plt.scatter(0, y1_26, marker='+',color='k')
legend_ms = plt.legend((ms26,ms19),['2.0°C ','1.5°C'], title='Mitigation scenario', loc=(4))
plt.gca().add_artist(legend_ms)
plt.axis()
plt.xlabel('year')
plt.legend(['PRISMAL1 - BL','PRISMAL1 - 1.5°C','PRISMAL2 - BL','PRISMAL2 - 1.5°C','PRISMAL3 - BL','PRISMAL4 - BL','PRISMAL4 - 2.0°C','PRISMAL5 - BL','PRISMAL5 - 1.5°C'], title='PRISMAL Scenarios', loc=(3))

#Vertical lines
lin1 = pd.Series([y1_2[2050],y1_1[2050]], [2050.75, 2050.75])
lin1.plot(color='green')
lin2 = pd.Series([y2_2[2050],y2_1[2050]], [2051.5, 2051.5])
lin2.plot(color='blue')
lin4 = pd.Series([y4_2[2050],y4_1[2050]], [2052.25, 2052.25])
lin4.plot(color='orange')
lin5 = pd.Series([y5_2[2050],y5_1[2050]], [2053, 2053])
lin5.plot(color='purple')

plt.ylabel(unit)
ax.set_ylim(ymin=0, ymax=20)
ax.set_xlim(xmin=2005, xmax=2054.5)
#plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.rc('axes', labelsize= 15)

# %%
p1_19 = prismal_all.loc(axis=0)['PRISMAL1','ms19',:,region, impact].loc(axis=1)[x].sum()
p2_19 = prismal_all.loc(axis=0)['PRISMAL2','ms19',:,region, impact].loc(axis=1)[x].sum()
p5_19 = prismal_all.loc(axis=0)['PRISMAL5','ms19',:,region, impact].loc(axis=1)[x].sum()
p1_26 = prismal_all.loc(axis=0)['PRISMAL1','ms26',:,region, impact].loc(axis=1)[x].sum()
p2_26 = prismal_all.loc(axis=0)['PRISMAL2','ms26',:,region, impact].loc(axis=1)[x].sum()
p4_26 = prismal_all.loc(axis=0)['PRISMAL4','ms26',:,region, impact].loc(axis=1)[x].sum()
p5_26 = prismal_all.loc(axis=0)['PRISMAL5','ms26',:,region, impact].loc(axis=1)[x].sum()
p19 = pd.DataFrame([p1_19, p2_19, p5_19], index=['P1','P2','P5'])
p26 = pd.DataFrame([p1_26, p2_26, p4_26, p5_26], index=['P1','P2','P4','P5'])

# %%
p1_19 = prismal_all.loc(axis=0)['PRISMAL1','ms19',:,region, impact].loc(axis=1)[x]
p1_19
# Out:
# Year                                                         2005       2010  \
# PRISMAL  MS   Stage                    Regions Impacts
# PRISMAL1 ms19 Bauxite                  GLO     GHG       0.035797   0.035797
#               Alumina                  GLO     GHG       2.434537   2.434537
#               Anode                    GLO     GHG       0.231936   0.231936
#               Electricity for smelting GLO     GHG      11.349688  11.822335
#               Smelting                 GLO     GHG       2.205268   2.205268
#               Casting                  GLO     GHG       0.247263   0.250534
#
# Year                                                         2020      2030  \
# PRISMAL  MS   Stage                    Regions Impacts
# PRISMAL1 ms19 Bauxite                  GLO     GHG       0.035797  0.035797
#               Alumina                  GLO     GHG       2.434537  2.434537
#               Anode                    GLO     GHG       0.231632  0.230585
#               Electricity for smelting GLO     GHG      10.406402  6.681048
#               Smelting                 GLO     GHG       2.201632  2.189109
#               Casting                  GLO     GHG       0.245658  0.228493
#
# Year                                                        2040      2050
# PRISMAL  MS   Stage                    Regions Impacts
# PRISMAL1 ms19 Bauxite                  GLO     GHG      0.035797  0.035797
#               Alumina                  GLO     GHG      2.434537  2.434537
#               Anode                    GLO     GHG      0.226104  0.209500
#               Electricity for smelting GLO     GHG      1.523118  0.912221
#               Smelting                 GLO     GHG      2.135514  1.936956
#               Casting                  GLO     GHG      0.202589  0.199532

# %%
1-(p26[2050]/p26[2020])
# Out:
# P1    0.485019
# P2    0.582094
# P4    0.635099
# P5    0.544806
# dtype: float64

# %%
#2100 horizon
#Global average impact for every PRISMAL scenarios and related mitigations scenarios
region = 'GLO'
impact = 'GHG'

#Unit for y axis
unit=''
if impact=='GHG':
    unit='GHG [kg CO2 eq / kg Al]'
    
if impact=='HH':
    unit='HH [DALY / kg Al]'
    
if impact=='EQ':
    unit='EQ [PDF·m2·yr/m3 / kg Al]'

    
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1, 1, 1)
x = prismal_all.columns

#PRISMAL1
y1_1 = prismal_all.loc(axis=0)['PRISMAL1','msbl',:,region, impact].sum()
y1_2 = prismal_all.loc(axis=0)['PRISMAL1','ms19',:,region, impact].sum()
ax.fill_between(x, y1_1, y1_2, facecolor='green', alpha=0.1)
y1_1.plot(color='green', linewidth=4)
y1_2.plot(color='green', ls='--', alpha=1)
y1_19 = prismal_all.loc(axis=0)['PRISMAL1','ms19',:,region, impact].loc(axis=1)[2100].sum()

#PRISMAL2
y2_1 = prismal_all.loc(axis=0)['PRISMAL2','msbl',:,region, impact].sum()
y2_2 = prismal_all.loc(axis=0)['PRISMAL2','ms19',:,region, impact].sum()
ax.fill_between(x, y2_1, y2_2, facecolor='blue', alpha=0.1)
y2_1.plot(color='blue', linewidth=4)
y2_2.plot(color='blue', ls='--', alpha=1)
y2_19 = prismal_all.loc(axis=0)['PRISMAL2','ms19',:,region, impact].loc(axis=1)[2100].sum()

#PRISMAL3
y3_1 = prismal_all.loc(axis=0)['PRISMAL3','msbl',:,region, impact].sum()
#y3_2 = prismal_all.loc(axis=0)['PRISMAL3','ms34',:,region, impact].sum()
#ax.fill_between(x, y3_1, y3_2, facecolor='red', alpha=0.1)
y3_1.plot(color='red', linewidth=4)
#y3_2.plot(color='red', ls='--', alpha=1)
#lin3 = pd.Series([y3_2[2100],y3_1[2100]], [2103, 2103])
#lin3.plot(color='red')

#PRISMAL4
y4_1 = prismal_all.loc(axis=0)['PRISMAL4','msbl',:,region, impact].sum()
y4_2 = prismal_all.loc(axis=0)['PRISMAL4','ms26',:,region, impact].sum()
ax.fill_between(x, y4_1, y4_2, facecolor='orange', alpha=0.1)
y4_1.plot(color='orange', linewidth=4)
y4_2.plot(color='orange', ls='--', alpha=1)
y4_26 = prismal_all.loc(axis=0)['PRISMAL4','ms26',:,region, impact].loc(axis=1)[2100].sum()

#PRISMAL5
y5_1 = prismal_all.loc(axis=0)['PRISMAL5','msbl',:,region, impact].sum()
y5_2 = prismal_all.loc(axis=0)['PRISMAL5','ms19',:,region, impact].sum()
ax.fill_between(x, y5_1, y5_2, facecolor='purple', alpha=0.1, edgecolor='orange')
y5_1.plot(color='purple', linewidth=4)
y5_2.plot(color='purple', ls='--', alpha=1)
y5_19 = prismal_all.loc(axis=0)['PRISMAL5','ms19',:,region, impact].loc(axis=1)[2100].sum()


#legend_scenario = plt.legend(['PRISMAL1 - BL','PRISMAL1 - 1.5°C','PRISMAL2 - BL','PRISMAL2 - 1.5°C','PRISMAL3 - BL','PRISMAL4 - BL','PRISMAL4 - 2.0°C','PRISMAL5 - BL','PRISMAL5 - 1.5°C'], title='PRISMAL Scenarios', loc=(1.03,0.2))
#plt.gca().add_artist(legend_scenario)

#Legend of Migigation scenario
ms19 = plt.scatter(0, y1_19, marker='*',color='k')
ms26 = plt.scatter(0, y1_26, marker='+',color='k')
legend_ms = plt.legend((ms26,ms19),['2.0°C ','1.5°C'], title='Mitigation scenario', loc=(4))
plt.gca().add_artist(legend_ms)
plt.axis()
plt.xlabel('year')
plt.legend(['PRISMAL1 - BL','PRISMAL1 - 1.5°C','PRISMAL2 - BL','PRISMAL2 - 1.5°C','PRISMAL3 - BL','PRISMAL4 - BL','PRISMAL4 - 2.0°C','PRISMAL5 - BL','PRISMAL5 - 1.5°C'], title='PRISMAL Scenarios', loc=(1.03,0.2))

#Vertical lines
lin1 = pd.Series([y1_2[2100],y1_1[2100]], [2101, 2101])
lin1.plot(color='green')
plt.scatter(2101, y1_19, marker='*', color='green')
y1_26 = prismal_all.loc(axis=0)['PRISMAL1','ms26',:,region, impact].loc(axis=1)[2100].sum()
plt.scatter(2101, y1_26, marker='+',color='green')
lin2 = pd.Series([y2_2[2100],y2_1[2100]], [2102, 2102])
lin2.plot(color='blue')
plt.scatter(2102, y2_19, marker='*', color='blue')
y2_26 = prismal_all.loc(axis=0)['PRISMAL2','ms26',:,region, impact].loc(axis=1)[2100].sum()
plt.scatter(2102, y2_26, marker='+',color='blue')
lin4 = pd.Series([y4_2[2100],y4_1[2100]], [2103, 2103])
lin4.plot(color='orange')
lin5 = pd.Series([y5_2[2100],y5_1[2100]], [2104, 2104])
plt.scatter(2103, y4_26, marker='+',color='orange')
lin5.plot(color='purple')
y5_26 = prismal_all.loc(axis=0)['PRISMAL5','ms26',:,region, impact].loc(axis=1)[2100].sum()
plt.scatter(2104, y5_26, marker='+',color='purple')
plt.scatter(2104, y5_19, marker='*',color='purple')

#plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.ylabel(unit)
ax.set_ylim(ymin=0)
ax.set_xlim(xmin=2005, xmax=2107)
plt.axvline(x=2050, color='grey', ls=':', lw=1)
plt.rc('axes', labelsize= 15)

y5_2
# Out:
# Year
# 2005    16.527610
# 2010    17.009102
# 2020    16.358089
# 2030    12.464006
# 2040     7.417073
# 2050     5.748244
# 2060     5.494771
# 2070     5.280222
# 2080     4.793517
# 2090     4.309361
# 2100     4.106153
# dtype: float64

# %% [markdown]
# ## Contribution, improvments and regions

# %%
#2050 time horizon
scenario = 'PRISMAL2'
region = 'GLO'
impact = 'GHG'
ms = 'msbl'

#Unit for y axis
unit=''
if impact=='GHG':
    unit='GHG [kg CO2 eq / kg Al]'
    
if impact=='HH':
    unit='HH [DALY / kg Al]'
    
if impact=='EQ':
    unit='EQ [PDF·m2·yr/m3 / kg Al]'

x = prismal_all.columns

#Stacked bar for life cycle stages
bauxite = prismal_all.loc[scenario,ms,'Bauxite',region,impact]
alumina = prismal_all.loc[scenario,ms,'Alumina',region,impact]
casting = prismal_all.loc[scenario,ms,'Casting',region,impact]
smelting_dir = prismal_all.loc(axis=0)[scenario,ms,'Anode', region, impact] + prismal_all.loc(axis=0)[scenario,ms,'Smelting', region, impact]
smelting_ind = prismal_all.loc(axis=0)[scenario,ms,'Electricity for smelting', region, impact]
energy_cha_imp = prismal_imp_all.loc[scenario,ms,'Changes in elec. mix', region, impact]
energy_int_imp = prismal_imp_all.loc[scenario,ms,'Energy int. imp.', region, impact]
inert_anode_deployment = prismal_imp_all.loc[scenario,ms,'Inert anode deployment', region, impact]

Contribution = pd.concat([bauxite, alumina, casting, smelting_dir, smelting_ind, energy_cha_imp, energy_int_imp, inert_anode_deployment], axis=1).T
Contribution.index = ['Bauxite mining', 'Alumina refining','Casting','Electrolysis', 'Electricity for smelting','Changes in elec. mix','Energy int. imp','Inert anode deployment']
Contribution.index.rename('Life cycle stages')

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(1, 1, 1)

plt.bar(x, inert_anode_deployment, 3.1, bottom = bauxite+alumina+casting+smelting_dir+smelting_ind+energy_cha_imp+energy_int_imp, color = 'grey', hatch='++', edgecolor='w')
plt.bar(x, energy_int_imp, 3.1, bottom = bauxite+alumina+casting+smelting_dir+smelting_ind+energy_cha_imp, color = 'darkgrey', hatch='////', edgecolor='w')
plt.bar(x, energy_cha_imp, 3.1, bottom = bauxite+alumina+casting+smelting_dir+smelting_ind, color = 'darkgrey', hatch='...', edgecolor='w')
plt.bar(x, smelting_ind, 3, bottom = bauxite+alumina+casting+smelting_dir, color='darkgrey')
plt.bar(x, smelting_dir, 3, bottom = bauxite+alumina+casting, color='grey')
plt.bar(x, casting, 3, bottom= bauxite+alumina, color='midnightblue')
plt.bar(x, alumina, 3, bottom=bauxite, color='peru')
plt.bar(x, bauxite, 3, color='darkgreen')

#Legends
legend_stages = plt.legend(['Inert anode deployment','Energy intensity improvment','Change of electricity mix','Smelting Electricity','Smelting','Casting','Alumina refining','Bauxite mining'], title='Life cycle stages', loc=(1.03, 0.0))
ax1 = plt.gca().add_artist(legend_stages)

#Regional evolution

glo = prismal_all.loc[scenario,ms,:,'GLO',impact].loc[:,[2005, 2010, 2020, 2030, 2040, 2050]].sum(axis=0)
asia = prismal_all.loc[scenario,ms,:,'Asia',impact].loc[:,[2005, 2010, 2020, 2030, 2040, 2050]].sum(axis=0)
lam = prismal_all.loc[scenario,ms,:,'LAM',impact].loc[:,[2005, 2010, 2020, 2030, 2040, 2050]].sum(axis=0)
maf = prismal_all.loc[scenario,ms,:,'MAF',impact].loc[:,[2005, 2010, 2020, 2030, 2040, 2050]].sum(axis=0)
oecd = prismal_all.loc[scenario,ms,:,'OECD',impact].loc[:,[2005, 2010, 2020, 2030, 2040, 2050]].sum(axis=0)
ref = prismal_all.loc[scenario,ms,:,'REF',impact].loc[:,[2005, 2010, 2020, 2030, 2040, 2050]].sum(axis=0)

plt.plot(glo, color='k', linewidth=2)
plt.plot(asia, color='k', marker='+', ls=':', markersize=6)
plt.plot(lam, color='k', ls=':', marker='2', markersize=8)
plt.plot(maf, color='k', ls=':', marker='*', markersize=6)
plt.plot(oecd, color='k', ls=':', marker='h', markersize=5)
plt.plot(ref, color='k', ls=':',marker='x', markersize=5)

plt.legend(['GLO', 'Asia    (64%)', 'LAM    (2%)','MAF    (12%)','OECD  (15%)','REF     (7%)'], title='Regions', loc=(1.03, 0.54))


ax.set_xlim(xmin=2000, xmax=2055)
ax.set_ylim(ymin=0, ymax=22)

print('Contribution analysis of %s with %s impact categorie in %s region' % (scenario, impact, region))
display(Contribution.loc[:,[2005, 2010, 2020, 2030, 2040, 2050]])
plt.rc('axes', labelsize= 15)

plt.show()
# Out:
# Contribution analysis of PRISMAL2 with GHG impact categorie in GLO region
# Year                           2005       2010       2020       2030  \
# Bauxite mining             0.035797   0.035797   0.035797   0.035797
# Alumina refining           2.434537   2.434537   2.434537   2.434537
# Casting                    0.247952   0.250232   0.246946   0.243952
# Electrolysis               2.437205   2.437205   2.432340   2.424072
# Electricity for smelting  11.498365  11.841870  10.883908  10.039801
# Changes in elec. mix      -0.000000  -0.485610   0.209287   0.814315
# Energy int. imp           -0.000000   0.142105   0.405170   0.644249
# Inert anode deployment     0.000000   0.000000   0.004865   0.013133
#
# Year                          2040      2050
# Bauxite mining            0.035797  0.035797
# Alumina refining          2.434537  2.434537
# Casting                   0.240964  0.240730
# Electrolysis              2.402167  2.346528
# Electricity for smelting  9.241147  9.019413
# Changes in elec. mix      1.393823  1.413156
# Energy int. imp           0.863395  1.065796
# Inert anode deployment    0.035038  0.090677

# %%
#2100 time horizon
scenario = 'PRISMAL2'
region = 'GLO'
impact = 'GHG'
ms = 'msbl'

#Unit for y axis
unit=''
if impact=='GHG':
    unit='GHG [kg CO2 eq / kg Al]'
    
if impact=='HH':
    unit='HH [DALY / kg Al]'
    
if impact=='EQ':
    unit='EQ [PDF·m2·yr/m3 / kg Al]'

x = prismal_all.columns


fig = plt.figure(figsize=(8,5))
ax = fig.add_subplot(1, 1, 1)

#Stacked bar for life cycle stages
bauxite = prismal_all.loc[scenario,ms,'Bauxite',region,impact]
alumina = prismal_all.loc[scenario,ms,'Alumina',region,impact]
casting = prismal_all.loc[scenario,ms,'Casting',region,impact]
smelting_dir = prismal_all.loc(axis=0)[scenario,ms,'Anode', region, impact] + prismal_all.loc(axis=0)[scenario,ms,'Smelting', region, impact]
smelting_ind = prismal_all.loc(axis=0)[scenario,ms,'Electricity for smelting', region, impact]
energy_cha_imp = prismal_imp_all.loc[scenario,ms,'Changes in elec. mix', region, impact]
energy_int_imp = prismal_imp_all.loc[scenario,ms,'Energy int. imp.', region, impact]
inert_anode_deployment = prismal_imp_all.loc[scenario,ms,'Inert anode deployment', region, impact]

Contribution = pd.concat([bauxite, alumina, casting, smelting_dir, smelting_ind, energy_cha_imp, energy_int_imp, inert_anode_deployment], axis=1).T
Contribution.index = ['Bauxite', 'Alumina','Casting','Electrolysis', 'Electricity for smelting','Changes in elec. mix','Energy int. imp','Inert anode deployment']
Contribution.index.rename('Life cycle stages')

plt.bar(x, inert_anode_deployment, 3.1, bottom = bauxite+alumina+casting+smelting_dir+smelting_ind+energy_cha_imp+energy_int_imp, color = 'grey', hatch='++', edgecolor='w')
plt.bar(x, energy_int_imp, 3.1, bottom = bauxite+alumina+casting+smelting_dir+smelting_ind+energy_cha_imp, color = 'darkgrey', hatch='////', edgecolor='w')
plt.bar(x, energy_cha_imp, 3.1, bottom = bauxite+alumina+casting+smelting_dir+smelting_ind, color = 'darkgrey', hatch='...', edgecolor='w')
plt.bar(x, smelting_ind, 3, bottom = bauxite+alumina+casting+smelting_dir, color='darkgrey')
plt.bar(x, smelting_dir, 3, bottom = bauxite+alumina+casting, color='grey')
plt.bar(x, casting, 3, bottom= bauxite+alumina, color='midnightblue')
plt.bar(x, alumina, 3, bottom=bauxite, color='peru')
plt.bar(x, bauxite, 3, color='darkgreen')


#Legends
legend_stages = plt.legend(['Inert anode deployment','Energy intensity improvment','Change of electricity mix','Smelting Electricity','Smelting','Casting','Alumina','Bauxite'], title='Life cycle stages', loc=(1.03, 0.0))
ax = plt.gca().add_artist(legend_stages)

#Regional evolution

glo = prismal_all.loc[scenario,ms,:,'GLO',impact].sum(axis=0)
asia = prismal_all.loc[scenario,ms,:,'Asia',impact].sum(axis=0)
lam = prismal_all.loc[scenario,ms,:,'LAM',impact].sum(axis=0)
maf = prismal_all.loc[scenario,ms,:,'MAF',impact].sum(axis=0)
oecd = prismal_all.loc[scenario,ms,:,'OECD',impact].sum(axis=0)
ref = prismal_all.loc[scenario,ms,:,'REF',impact].sum(axis=0)
plt.plot(glo, color='k', linewidth=2)
plt.plot(asia, color='k', marker='+', ls=':', markersize=6)
plt.plot(lam, color='k', ls=':', marker='2', markersize=8)
plt.plot(maf, color='k', ls=':', marker='*', markersize=6)
plt.plot(oecd, color='k', ls=':', marker='h', markersize=5)
plt.plot(ref, color='k', ls=':',marker='x', markersize=5)
plt.legend(['GLO', 'Asia    (64%)', 'LAM    (2%)','MAF    (12%)','OECD  (15%)','REF     (7%)'], title='Regions', loc=(1.03, 0.54))


y_axe = plt.ylabel(unit)
x_axe = plt.xlabel('year')

print('Contribution analysis of %s with %s impact categorie in %s region' % (scenario, impact, region))
display(Contribution)
plt.rc('axes', labelsize= 15)
plt.show()
# Out:
# Contribution analysis of PRISMAL2 with GHG impact categorie in GLO region
# Year                           2005       2010       2020       2030  \
# Bauxite                    0.035797   0.035797   0.035797   0.035797
# Alumina                    2.434537   2.434537   2.434537   2.434537
# Casting                    0.247952   0.250232   0.246946   0.243952
# Electrolysis               2.437205   2.437205   2.432340   2.424072
# Electricity for smelting  11.498365  11.841870  10.883908  10.039801
# Changes in elec. mix      -0.000000  -0.485610   0.209287   0.814315
# Energy int. imp           -0.000000   0.142105   0.405170   0.644249
# Inert anode deployment     0.000000   0.000000   0.004865   0.013133
#
# Year                          2040      2050      2060      2070      2080  \
# Bauxite                   0.035797  0.035797  0.035797  0.035797  0.035797
# Alumina                   2.434537  2.434537  2.434537  2.434537  2.434537
# Casting                   0.240964  0.240730  0.240743  0.240043  0.238812
# Electrolysis              2.402167  2.346528  2.219144  1.985914  1.693152
# Electricity for smelting  9.241147  9.019413  8.859360  8.574903  8.205131
# Changes in elec. mix      1.393823  1.413156  1.385010  1.493418  1.697613
# Energy int. imp           0.863395  1.065796  1.253995  1.430045  1.595621
# Inert anode deployment    0.035038  0.090677  0.218061  0.451291  0.744053
#
# Year                          2090      2100
# Bauxite                   0.035797  0.035797
# Alumina                   2.434537  2.434537
# Casting                   0.233843  0.227948
# Electrolysis              1.459922  1.332538
# Electricity for smelting  7.167318  5.996951
# Changes in elec. mix      2.578943  3.600771
# Energy int. imp           1.752104  1.900643
# Inert anode deployment    0.977283  1.104667

# %% [markdown]
# ## Total

# %%
prod_m_data = pd.Series([31394,35430,39559,41632,39087,44708,49752,51208,53734,57187,58872,59709,65731,64557, 67347, 70059, 73294,74161,75861,77784,79923,81588,83300,84842,86490,88192,88567,89025,89518,90051,90629,91256,91932,92660,93441,94276, 100000],
                             [2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025,2026,2027,2028,2029,2030,2031,2032,2033,2034,2035,2036,2037,2038,2039,2040,2050])/1000

# %%
#Total impact for every PRISMAL scenario and total production
x = prismal_total.columns
ms='msbl'
impact= 'GHG'

prismal_tot_GT = prismal_total/1000000000
fig = plt.figure(figsize=(8,6))
ax1 = fig.add_subplot(1, 1, 1)

#PRISMAL1
y1_1 = prismal_tot_GT.loc(axis=0)['PRISMAL1',ms,:,region,impact].sum()
y1_2 = prismal_tot_GT.loc(axis=0)['PRISMAL1','ms19',:,region,impact].sum()
plt.plot(y1_1, color='green', linewidth=2)
y1_19 = prismal_tot_GT.loc(axis=0)['PRISMAL1','ms19',:,region, impact].loc(axis=1)[2050].sum()
y1_26 = prismal_tot_GT.loc(axis=0)['PRISMAL1','ms26',:,region, impact].loc(axis=1)[2050].sum()
plt.scatter(2050.75, y1_19, marker='*', color='green')
plt.scatter(2050.75, y1_26, marker='+',color='green')

#PRISMAL2
y2_1 = prismal_tot_GT.loc(axis=0)['PRISMAL2',ms,:,region,impact].sum()
y2_2 = prismal_tot_GT.loc(axis=0)['PRISMAL2','ms19',:,region,impact].sum()
plt.plot(y2_1, color='blue', linewidth=2)
plt.plot(y2_2, color='blue', linewidth=2, ls='-.')
plt.fill_between(x, y2_1, y2_2, facecolor='blue', alpha=0.1)
y2_19 = prismal_tot_GT.loc(axis=0)['PRISMAL2','ms19',:,region, impact].loc(axis=1)[2050].sum()
plt.scatter(2051.5, y2_19, marker='*', color='blue')
y2_26 = prismal_tot_GT.loc(axis=0)['PRISMAL2','ms26',:,region, impact].loc(axis=1)[2050].sum()
plt.scatter(2051.5, y2_26, marker='+',color='blue')

#PRISMAL3
y3_1 = prismal_tot_GT.loc(axis=0)['PRISMAL3',ms,:,region,impact].sum()
y3_2 = prismal_tot_GT.loc(axis=0)['PRISMAL3','ms34',:,region,impact].sum()
plt.plot(y3_1, color='red', linewidth=2)

#PRISMAL4
y4_1 = prismal_tot_GT.loc(axis=0)['PRISMAL4',ms,:,region,impact].sum()
y4_2 = prismal_tot_GT.loc(axis=0)['PRISMAL4','ms26',:,region,impact].sum()
plt.plot(y4_1, color='orange', linewidth=2)
y4_26 = prismal_tot_GT.loc(axis=0)['PRISMAL4','ms26',:,region, impact].loc(axis=1)[2050].sum()
plt.scatter(2052.25, y4_26, marker='+',color='orange')

#PRISMAL5
y5_1 = prismal_tot_GT.loc(axis=0)['PRISMAL5',ms,:,region,impact].sum()
y5_2 = prismal_tot_GT.loc(axis=0)['PRISMAL5','ms19',:,region,impact].sum()
plt.plot(y5_1, color='purple', linewidth=2)
y5_19 = prismal_tot_GT.loc(axis=0)['PRISMAL5','ms19',:,region, impact].loc(axis=1)[2050].sum()
y5_26 = prismal_tot_GT.loc(axis=0)['PRISMAL5','ms26',:,region, impact].loc(axis=1)[2050].sum()
plt.scatter(2053, y5_19, marker='*', color='purple')
plt.scatter(2053, y5_26, marker='+', color='purple')

#PRISMAL Legend
ax1.set_ylim(ymin=0, ymax=2500)
plt.xlabel('year')
plt.ylabel('GHG [MT CO2 eq]')
plt.legend(['PRISMAL1','PRISMAL2','PRISMAL2 - 1.5°C','PRISMAL3','PRISMAL4','PRISMAL5'], title='Scenario (Left axis)', loc=(2))

#Vertical lines
lin1 = pd.Series([y1_2[2050],y1_1[2050]], [2050.75, 2050.75])
lin1.plot(color='green')
lin2 = pd.Series([y2_2[2050],y2_1[2050]], [2051.5, 2051.5])
lin2.plot(color='blue')
lin4 = pd.Series([y4_2[2050],y4_1[2050]], [2052.25, 2052.25])
lin4.plot(color='orange')
lin5 = pd.Series([y5_2[2050],y5_1[2050]], [2053, 2053])
lin5.plot(color='purple')

#Total production volume
color = 'darkred'
ax2 = ax1.twinx()
ax2.set_ylabel('Mt of aluminium', color=color)
ax2.plot(prod_m_data, color=color, linewidth=3, linestyle='--')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(ymin=0, ymax=120)
plt.yticks()


#Axis and legends
legend_prod = plt.legend(['Aluminium production'], title='(Right axis)', loc=(1))

ms19 = plt.scatter(2060, y1_19, marker='*',color='k')
ms26 = plt.scatter(2060, y1_26, marker='+',color='k')
legend_ms = plt.legend((ms26,ms19),['2.0°C ','1.5°C'], title='Mitigation scenario', loc=(4))
plt.gca().add_artist(legend_ms)


ax1.set_xlim(xmin=2004, xmax=2055)
plt.gca().add_artist(legend_prod)
plt.rc('axes', labelsize= 15)
plt.show()

# %% [markdown]
# ## Sensibility geography

# %%
#Creaction of scenario for sensitivity analysis
PRISMAL2_sag0 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL2','Baseline', 'prod_geo_bl')
PRISMAL2_sag1 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL2','Baseline', 'prod_geo_sag1')
PRISMAL2_sag2 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL2','Baseline', 'prod_geo_sag2')
PRISMAL2_sag3 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL2','Baseline', 'prod_geo_sag3')
PRISMAL2_sag4 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL2','Baseline', 'prod_geo_sag4')
PRISMAL2_sag5 = Prismal.from_template('PRISMAL_data.xlsx', 'PRISMAL2','Baseline', 'prod_geo_sag5')

#Solving scenarios
PRISMAL2_sag0.solve()
PRISMAL2_sag1.solve()
PRISMAL2_sag2.solve()
PRISMAL2_sag3.solve()
PRISMAL2_sag4.solve()
PRISMAL2_sag5.solve()

#Agreagtion into one table
prismal2_sag0 = pd.concat([PRISMAL2_sag0.i_al_prod], keys=['sag0'])
prismal2_sag1 = pd.concat([PRISMAL2_sag1.i_al_prod], keys=['sag1'])
prismal2_sag2 = pd.concat([PRISMAL2_sag2.i_al_prod], keys=['sag2'])
prismal2_sag3 = pd.concat([PRISMAL2_sag3.i_al_prod], keys=['sag3'])
prismal2_sag4 = pd.concat([PRISMAL2_sag4.i_al_prod], keys=['sag4'])
prismal2_sag5 = pd.concat([PRISMAL2_sag5.i_al_prod], keys=['sag5'])
prismal2_sag = pd.concat([prismal2_sag0,prismal2_sag1,prismal2_sag2,prismal2_sag3,prismal2_sag4,prismal2_sag5])

# %%
#Sensitivity analysis of future geographical market share
prod = PRISMAL2_sag0.production/1000000000
n_prod = pd.Series([0,0,0, prod[2030]-prod[2020], prod[2040]-prod[2030], prod[2050]-prod[2040]], index = [2005,2010,2020,2030,2040,2050])
e_prod = prod-n_prod


region = 'GLO'
impact = 'GHG'

#Unit for y axis
unit=''
if impact=='GHG':
    unit='GHG [kg CO2 eq / kg Al]'
    
if impact=='HH':
    unit='HH [DALY / kg Al]'
    
if impact=='EQ':
    unit='EQ [PDF·m2·yr/m3 / kg Al]'

fig = plt.figure(figsize=(8,6))
ax1 = fig.add_subplot(1, 1, 1)

#Global relative impacts
y0 = prismal2_sag.loc(axis=0)['sag0', :,region, impact].loc[:,[2005,2010,2020,2030,2040,2050]].sum()
y0.plot(color='black', linewidth=2)
y1 = prismal2_sag.loc(axis=0)['sag1', :,region, impact].loc[:,[2005,2010,2020,2030,2040,2050]].sum()
y1.plot(color='blue', linewidth=2)
y2 = prismal2_sag.loc(axis=0)['sag2', :,region, impact].loc[:,[2005,2010,2020,2030,2040,2050]].sum()
y2.plot(color='red', linewidth=2)
y3 = prismal2_sag.loc(axis=0)['sag3', :,region, impact].loc[:,[2005,2010,2020,2030,2040,2050]].sum()
y3.plot(color='orange', linewidth=2)
y4 = prismal2_sag.loc(axis=0)['sag4', :,region, impact].loc[:,[2005,2010,2020,2030,2040,2050]].sum()
y4.plot(color='green', linewidth=2)
y5 = prismal2_sag.loc(axis=0)['sag5', :,region, impact].loc[:,[2005,2010,2020,2030,2040,2050]].sum()
y5.plot(color='purple', linewidth=2)

#Axis and legend
plt.axis()
plt.xlabel('year')
plt.legend(['Same proportion','50% Asia / 50% MAF ','100% MAF', '100% Asia', '100% LAM','Equally split'], title='PRISMAL2', loc=(1.15, 0.5))
plt.ylabel(unit)
#plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
ax1.set_ylim(ymin=0, ymax=17.5)
ax1.set_xlim(xmin=2003, xmax=2052)

sag = pd.DataFrame([y0,y1,y2,y3,y4,y5], index=['sag0','sag1 - 50% Asia / 50% MAF ','sag2 - 100% MAF', 'sag3 - 100% Asia', 'sag4 - 100% LAM','sag5 - equally split']).loc[:,[2005,2010,2020,2030,2040,2050]]
display(sag)

#Total production and part of new production
ax2 = ax1.twinx()
color='grey'
ax2.set_ylabel('Aluminium production [Mt Al]', color=color)

x = prod.index
plt.bar(x, e_prod, 3, color=color)
plt.bar(x, n_prod, 3, bottom=e_prod, color=color, hatch='///')

#Legend
legend_prod = plt.legend(['Existing','New'], title='Production', loc=(1.20, 0.3))
ax = plt.gca().add_artist(legend_prod)

#Axis
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(ymin=0, ymax=160)
# Out:
#                                  2005       2010       2020       2030  \
# sag0                        16.653856  16.999641  16.033528  15.178158
# sag1 - 50% Asia / 50% MAF   16.653856  16.999641  16.033528  15.213831
# sag2 - 100% MAF             16.653856  16.999641  16.033528  14.985951
# sag3 - 100% Asia            16.653856  16.999641  16.033528  15.441711
# sag4 - 100% LAM             16.653856  16.999641  16.033528  14.213807
# sag5 - equally split        16.653856  16.999641  16.033528  14.766311
#
#                                  2040       2050
# sag0                        14.354612  14.077006
# sag1 - 50% Asia / 50% MAF   14.384235  14.081911
# sag2 - 100% MAF             14.167992  13.815982
# sag3 - 100% Asia            14.600477  14.347840
# sag4 - 100% LAM             13.307508  12.907418
# sag5 - equally split        13.924290  13.586989
# (0, 160)

# %% [markdown]
# ## Sensitivity Electricity mix

# %%
a1bl = PRISMAL1_bl.i_elec_kWh.loc(axis=0)[:,'GHG']
b1bl = PRISMAL1_bl.d_alu_prod
c1bl = a1bl.mul(b1bl, level=0).sum()
a119 = PRISMAL1_19.i_elec_kWh.loc(axis=0)[:,'GHG']
b119 = PRISMAL1_19.d_alu_prod
c119 = a119.mul(b119, level=0).sum()
a126 = PRISMAL1_26.i_elec_kWh.loc(axis=0)[:,'GHG']
b126 = PRISMAL1_26.d_alu_prod
c126 = a126.mul(b126, level=0).sum()

a2bl = PRISMAL2_bl.i_elec_kWh.loc(axis=0)[:,'GHG']
b2bl = PRISMAL2_bl.d_alu_prod
c2bl = a2bl.mul(b2bl, level=0).sum()
a219 = PRISMAL2_19.i_elec_kWh.loc(axis=0)[:,'GHG']
b219 = PRISMAL2_19.d_alu_prod
c219 = a219.mul(b219, level=0).sum()
a226 = PRISMAL2_26.i_elec_kWh.loc(axis=0)[:,'GHG']
b226 = PRISMAL2_26.d_alu_prod
c226 = a226.mul(b226, level=0).sum()

a3bl = PRISMAL3_bl.i_elec_kWh.loc(axis=0)[:,'GHG']
b3bl = PRISMAL3_bl.d_alu_prod
c3bl= a3bl.mul(b3bl, level=0).sum()

a4bl = PRISMAL4_bl.i_elec_kWh.loc(axis=0)[:,'GHG']
b4bl = PRISMAL4_bl.d_alu_prod
c4bl = a4bl.mul(b4bl, level=0).sum()
a426 = PRISMAL4_26.i_elec_kWh.loc(axis=0)[:,'GHG']
b426 = PRISMAL4_26.d_alu_prod
c426 = a426.mul(b426, level=0).sum()
c426[2005] = c4bl[2005]


a5bl = PRISMAL5_bl.i_elec_kWh.loc(axis=0)[:,'GHG']
b5bl = PRISMAL5_bl.d_alu_prod
c5bl = a5bl.mul(b5bl, level=0).sum()
a519 = PRISMAL5_19.i_elec_kWh.loc(axis=0)[:,'GHG']
b519 = PRISMAL5_19.d_alu_prod
c519 = a519.mul(b519, level=0).sum()
a526 = PRISMAL5_26.i_elec_kWh.loc(axis=0)[:,'GHG']
b526 = PRISMAL5_26.d_alu_prod
c526 = a526.mul(b526, level=0).sum()

co2_kwh_prismal = pd.DataFrame([c1bl, c119, c126, c2bl, c219, c226, c3bl, c4bl, c426, c5bl, c519, c526], 
                               index=['P1bl', 'P119', 'P126', 'P2bl', 'P219', 'P226', 'P3bl', 'P4bl', 'P426', 'P5bl', 'P519', 'P526'])
co2_kwh_prismal
# Out:
#           2005      2010      2020      2030      2040      2050      2060  \
# P1bl  0.783431  0.832128  0.835484  0.799146  0.777390  0.709239  0.669168
# P119  0.783431  0.832128  0.759536  0.504036  0.118444  0.072943  0.066525
# P126  0.783431  0.832128  0.824588  0.680500  0.471592  0.291152  0.167792
# P2bl  0.793694  0.827633  0.778720  0.734148  0.689672  0.686183  0.686389
# P219  0.793767  0.829322  0.754402  0.253746  0.085359  0.050548  0.039401
# P226  0.793687  0.827614  0.750979  0.447175  0.254001  0.115521  0.080397
# P3bl  0.779831  0.845155  0.897104  0.923300  0.949605  0.968229  0.985010
# P4bl  0.804098  0.847875  0.904004  0.838678  0.759833  0.695177  0.646186
# P426  0.804098  0.847875  0.887558  0.374847  0.165117  0.101633  0.073296
# P5bl  0.785020  0.828291  0.837307  0.849825  0.897429  0.925495  0.934250
# P519  0.785020  0.828291  0.801498  0.535758  0.172193  0.050228  0.036085
# P526  0.785020  0.828291  0.801498  0.604408  0.372318  0.178742  0.093831
#
#           2070      2080      2090      2100
# P1bl  0.615920  0.527968  0.487902  0.473836
# P119  0.073929  0.065047  0.051513  0.038859
# P126  0.120369  0.097258  0.095123  0.096877
# P2bl  0.675966  0.657632  0.583676  0.495924
# P219  0.033145  0.030412  0.032151  0.036776
# P226  0.057948  0.042532  0.038360  0.038042
# P3bl  1.008632  1.025734  1.041199  1.048340
# P4bl  0.606352  0.505928  0.429853  0.374128
# P426  0.051965  0.030478  0.019377 -0.000809
# P5bl  0.910639  0.834954  0.706449  0.552015
# P519  0.036761  0.038923  0.041325  0.042944
# P526  0.063261  0.046526  0.042357  0.042552

# %%
PRISMAL1_19_SSP = PRISMAL1_19
PRISMAL1_26_SSP = PRISMAL1_26
PRISMAL1_bl_SSP = PRISMAL1_bl
PRISMAL2_19_SSP = PRISMAL2_19
PRISMAL2_26_SSP = PRISMAL2_26
PRISMAL2_bl_SSP = PRISMAL2_bl
PRISMAL3_bl_SSP = PRISMAL3_bl
PRISMAL4_26_SSP = PRISMAL4_26
PRISMAL4_bl_SSP = PRISMAL4_bl
PRISMAL5_19_SSP = PRISMAL5_19
PRISMAL5_26_SSP = PRISMAL5_26
PRISMAL5_bl_SSP = PRISMAL5_bl

# %%
imp_elec_ssp = pd.read_excel('PRISMAL_data.xlsx', index_col=[0,1,2,3],  sheet_name='impacts_elec_SSP')

PRISMAL1_19_SSP.i_elec_kWh.loc(axis=0)[:,'GHG'] = imp_elec_ssp.loc['PRISMAL1'].loc['MS19']
PRISMAL1_26_SSP.i_elec_kWh.loc(axis=0)[:,'GHG'] = imp_elec_ssp.loc['PRISMAL1'].loc['MS26']
PRISMAL1_bl_SSP.i_elec_kWh.loc(axis=0)[:,'GHG'] = imp_elec_ssp.loc['PRISMAL1'].loc['Baseline']
PRISMAL2_19_SSP.i_elec_kWh.loc(axis=0)[:,'GHG'] = imp_elec_ssp.loc['PRISMAL2'].loc['MS19']
PRISMAL2_26_SSP.i_elec_kWh.loc(axis=0)[:,'GHG'] = imp_elec_ssp.loc['PRISMAL2'].loc['MS26']
PRISMAL2_bl_SSP.i_elec_kWh.loc(axis=0)[:,'GHG'] = imp_elec_ssp.loc['PRISMAL2'].loc['Baseline']
PRISMAL3_bl_SSP.i_elec_kWh.loc(axis=0)[:,'GHG'] = imp_elec_ssp.loc['PRISMAL3'].loc['Baseline']
PRISMAL4_26_SSP.i_elec_kWh.loc(axis=0)[:,'GHG'] = imp_elec_ssp.loc['PRISMAL4'].loc['MS26']
PRISMAL4_bl_SSP.i_elec_kWh.loc(axis=0)[:,'GHG'] = imp_elec_ssp.loc['PRISMAL4'].loc['Baseline']
PRISMAL5_19_SSP.i_elec_kWh.loc(axis=0)[:,'GHG'] = imp_elec_ssp.loc['PRISMAL5'].loc['MS19']
PRISMAL5_26_SSP.i_elec_kWh.loc(axis=0)[:,'GHG'] = imp_elec_ssp.loc['PRISMAL5'].loc['MS26']
PRISMAL5_bl_SSP.i_elec_kWh.loc(axis=0)[:,'GHG'] = imp_elec_ssp.loc['PRISMAL5'].loc['Baseline']

# %%
PRISMAL1_19_SSP.solve_sens_elec()
PRISMAL1_26_SSP.solve_sens_elec()
PRISMAL1_bl_SSP.solve_sens_elec()
PRISMAL2_19_SSP.solve_sens_elec()
PRISMAL2_26_SSP.solve_sens_elec()
PRISMAL2_bl_SSP.solve_sens_elec()
PRISMAL3_bl_SSP.solve_sens_elec()
PRISMAL4_26_SSP.solve_sens_elec()
PRISMAL4_bl_SSP.solve_sens_elec()
PRISMAL5_19_SSP.solve_sens_elec()
PRISMAL5_26_SSP.solve_sens_elec()
PRISMAL5_bl_SSP.solve_sens_elec()

# %%
prismal1_19_SSP = pd.concat([PRISMAL1_bl_SSP.i_al_prod], keys=['ms19'])
prismal1_19_SSP = pd.concat([prismal1_19_SSP], keys=['PRISMAL1'])
prismal1_26_SSP = pd.concat([PRISMAL1_26_SSP.i_al_prod], keys=['ms26'])
prismal1_26_SSP = pd.concat([prismal1_26_SSP], keys=['PRISMAL1'])
prismal1_bl_SSP = pd.concat([PRISMAL1_bl_SSP.i_al_prod], keys=['msbl'])
prismal1_bl_SSP = pd.concat([prismal1_bl_SSP], keys=['PRISMAL1'])
prismal1_SSP = pd.concat([prismal1_19_SSP,prismal1_26_SSP,prismal1_bl_SSP])

prismal2_19_SSP = pd.concat([PRISMAL2_19_SSP.i_al_prod], keys=['ms19'])
prismal2_19_SSP = pd.concat([prismal2_19_SSP], keys=['PRISMAL2'])
prismal2_26_SSP = pd.concat([PRISMAL2_26_SSP.i_al_prod], keys=['ms26'])
prismal2_26_SSP = pd.concat([prismal2_26_SSP], keys=['PRISMAL2'])
prismal2_bl_SSP = pd.concat([PRISMAL2_bl_SSP.i_al_prod], keys=['msbl'])
prismal2_bl_SSP = pd.concat([prismal2_bl_SSP], keys=['PRISMAL2'])
prismal2_SSP = pd.concat([prismal2_19_SSP,prismal2_26_SSP,prismal2_bl_SSP])

prismal3_bl_SSP = pd.concat([PRISMAL3_bl_SSP.i_al_prod], keys=['msbl'])
prismal3_bl_SSP = pd.concat([prismal3_bl_SSP], keys=['PRISMAL3'])
prismal3_SSP = pd.concat([prismal3_bl_SSP])

prismal4_26_SSP = pd.concat([PRISMAL4_26_SSP.i_al_prod], keys=['ms26'])
prismal4_26_SSP = pd.concat([prismal4_26_SSP], keys=['PRISMAL4'])
prismal4_bl_SSP = pd.concat([PRISMAL4_bl_SSP.i_al_prod], keys=['msbl'])
prismal4_bl_SSP = pd.concat([prismal4_bl_SSP], keys=['PRISMAL4'])
prismal4_SSP = pd.concat([prismal4_26_SSP,prismal4_bl_SSP])

prismal5_19_SSP = pd.concat([PRISMAL5_19_SSP.i_al_prod], keys=['ms19'])
prismal5_19_SSP = pd.concat([prismal5_19_SSP], keys=['PRISMAL5'])
prismal5_26_SSP = pd.concat([PRISMAL5_26_SSP.i_al_prod], keys=['ms26'])
prismal5_26_SSP = pd.concat([prismal5_26_SSP], keys=['PRISMAL5'])
prismal5_bl_SSP = pd.concat([PRISMAL5_bl_SSP.i_al_prod], keys=['msbl'])
prismal5_bl_SSP = pd.concat([prismal5_bl_SSP], keys=['PRISMAL5'])
prismal5_SSP = pd.concat([prismal5_19_SSP,prismal5_26_SSP,prismal5_bl_SSP])

prismal_all_SSP = pd.concat([prismal1_SSP, prismal2_SSP, prismal3_SSP, prismal4_SSP, prismal5_SSP])

# %%
#2050 time horizon
#Global average impact for every PRISMAL scenarios and related mitigations scenarios
scenario = 'PRISMAL2'
region = 'GLO'
impact = 'GHG'

#Unit for y axis
unit=''
if impact=='GHG':
    unit='GHG [kg CO2 eq / kg Al]'
    
if impact=='HH':
    unit='HH [DALY / kg Al]'
    
if impact=='EQ':
    unit='EQ [PDF·m2·yr/m3 / kg Al]'

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1, 1, 1)
x = [2005,2010,2020,2030,2040,2050]

#PRISMAL
y_19 = prismal_all.loc(axis=0)[scenario, 'ms19',:,region, impact].loc(axis=1)[x].sum()
y_26 = prismal_all.loc(axis=0)[scenario, 'ms26',:,region, impact].loc(axis=1)[x].sum()
y_bl = prismal_all.loc(axis=0)[scenario, 'msbl',:,region, impact].loc(axis=1)[x].sum()

y_19.plot(color='blue', ls=':', linewidth=2)
y_26.plot(color='blue', ls='--', linewidth=2)
y_bl.plot(color='blue', linewidth=3)

#PRISMAL_SSP
y_19_ssp = prismal_all_SSP.loc(axis=0)[scenario, 'ms19',:,region, impact].loc(axis=1)[x].sum()
y_26_ssp = prismal_all_SSP.loc(axis=0)[scenario, 'ms26',:,region, impact].loc(axis=1)[x].sum()
y_bl_ssp = prismal_all_SSP.loc(axis=0)[scenario, 'msbl',:,region, impact].loc(axis=1)[x].sum()

y_19_ssp.plot(color='purple', ls=':', linewidth=2)
y_26_ssp.plot(color='purple', ls='--', linewidth=2)
y_bl_ssp.plot(color='purple', linewidth=3)

#Vertical lines
lin1 = pd.Series([y_bl[2050],y_19[2050]], [2050.75, 2050.75])
lin1.plot(color='blue')
lin2 = pd.Series([y_bl_ssp[2050],y_19_ssp[2050]], [2051.25, 2051.25])
lin2.plot(color='purple')

plt.ylabel(unit)
ax.set_ylim(ymin=0, ymax=20)
ax.set_xlim(xmin=2005, xmax=2053)
#plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.rc('axes', labelsize= 15)

#Legend
plt.legend(['1.5°C','2.0°C','Baseline','1.5°C - SSP','2.0°C - SSP','Baseline - SSP'],title=scenario, loc=(1.03, 0.3))

# %%
#2100 time horizon
#Global average impact for every PRISMAL scenarios and related mitigations scenarios
scenario = 'PRISMAL1'
region = 'GLO'
impact = 'GHG'

#Unit for y axis
unit=''
if impact=='GHG':
    unit='GHG [kg CO2 eq / kg Al]'
    
if impact=='HH':
    unit='HH [DALY / kg Al]'
    
if impact=='EQ':
    unit='EQ [PDF·m2·yr/m3 / kg Al]'

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1, 1, 1)
x = [2005,2010,2020,2030,2040,2050,2060,2070,2080,2090,2100]

#PRISMAL
y_19 = prismal_all.loc(axis=0)[scenario, 'ms19',:,region, impact].loc(axis=1)[x].sum()
y_26 = prismal_all.loc(axis=0)[scenario, 'ms26',:,region, impact].loc(axis=1)[x].sum()
y_bl = prismal_all.loc(axis=0)[scenario, 'msbl',:,region, impact].loc(axis=1)[x].sum()

y_19.plot(color='blue', ls=':', linewidth=2)
y_26.plot(color='blue', ls='--', linewidth=2)
y_bl.plot(color='blue', linewidth=3)

#PRISMAL_SSP
y_19_ssp = prismal_all_SSP.loc(axis=0)[scenario, 'ms19',:,region, impact].loc(axis=1)[x].sum()
y_26_ssp = prismal_all_SSP.loc(axis=0)[scenario, 'ms26',:,region, impact].loc(axis=1)[x].sum()
y_bl_ssp = prismal_all_SSP.loc(axis=0)[scenario, 'msbl',:,region, impact].loc(axis=1)[x].sum()

y_19_ssp.plot(color='purple', ls=':', linewidth=2)
y_26_ssp.plot(color='purple', ls='--', linewidth=2)
y_bl_ssp.plot(color='purple', linewidth=3)

#Vertical lines
lin1 = pd.Series([y_bl[2100],y_19[2100]], [2102, 2102])
lin1.plot(color='blue')
lin2 = pd.Series([y_26_ssp[2100],y_bl_ssp[2100]], [2103, 2103])
lin2.plot(color='purple')

plt.ylabel(unit)
ax.set_ylim(ymin=0, ymax=20)
ax.set_xlim(xmin=2005, xmax=2104)
#plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.rc('axes', labelsize= 15)

#Legend
plt.legend(['1.5°C','2.0°C','Baseline','1.5°C - SSP','2.0°C - SSP','Baseline - SSP'],title=scenario, loc=(1))

# %%
scenario = 'PRISMAL1'
print(prismal_all_SSP.loc(axis=0)[scenario, 'msbl',:,region, impact].loc(axis=1)[x].sum())
prismal_all_SSP.loc(axis=0)[scenario, 'ms19',:,region, impact].loc(axis=1)[x].sum()
# Out:
# 2005    13.713550
# 2010    13.547992
# 2020    12.828465
# 2030    11.627019
# 2040    10.644515
# 2050     9.545905
# 2060     8.475079
# 2070     7.412787
# 2080     6.526388
# 2090     6.098034
# 2100     5.883754
# dtype: float64
# 2005    13.713550
# 2010    13.547992
# 2020    12.828465
# 2030    11.627019
# 2040    10.644515
# 2050     9.545905
# 2060     8.475079
# 2070     7.412787
# 2080     6.526388
# 2090     6.098034
# 2100     5.883754
# dtype: float64

# %%
print(prismal_all_SSP.loc(axis=0)[scenario, 'msbl','Electricity for smelting','GLO', impact].loc(axis=1)[x].s
# Out:
#   File "<ipython-input-29-463a86abfa5f>", line 1
#     print(prismal_all_SSP.loc(axis=0)[scenario, 'msbl','Electricity for smelting','GLO', impact].loc(axis=1)[x].s
#                                                                                                                  ^
# SyntaxError: unexpected EOF while parsing

# %%
print(prismal_all_SSP.loc(axis=0)[scenario, 'ms26','Electricity for smelting','GLO', impact])

# %% [markdown]
# ## Contribution

# %%
#Contribution analysis
scenario = 'PRISMAL2'
region = 'GLO'
impact = 'GHG'
ms = 'msbl'

#Unit for y axis
unit=''
if impact=='GHG':
    unit='GHG [kg CO2 eq / kg Al]'
    
if impact=='HH':
    unit='HH [DALY / kg Al]'
    
if impact=='EQ':
    unit='EQ [PDF·m2·yr/m3 / kg Al]'

#Plot figure
x = prismal_all.columns

y = prismal_all.loc[scenario,ms, :, region,impact]
y.index= y.index.droplevel([0,1,3,4])

y.T.plot(kind='bar', stacked=True)
plt.xlabel('year')
plt.ylabel(unit)
plt.legend(title= 'Life cycle stages', loc=(1.03, 0.25))

print('Contribution analysis of %s with %s impact categorie in %s region' % (scenario, impact, region))
display(y)
plt.show()
# Out:
# Contribution analysis of PRISMAL2 with GHG impact categorie in GLO region
# Year                           2005       2010       2020       2030  \
# Stage
# Bauxite                    0.035797   0.035797   0.035797   0.035797
# Alumina                    2.434537   2.434537   2.434537   2.434537
# Anode                      0.231936   0.231936   0.231561   0.230923
# Electricity for smelting  11.498365  11.841870  10.883908  10.039801
# Smelting                   2.205268   2.205268   2.200779   2.193149
# Casting                    0.247952   0.250232   0.246946   0.243952
#
# Year                          2040      2050      2060      2070      2080  \
# Stage
# Bauxite                   0.035797  0.035797  0.035797  0.035797  0.035797
# Alumina                   2.434537  2.434537  2.434537  2.434537  2.434537
# Anode                     0.229233  0.224939  0.215109  0.197112  0.174520
# Electricity for smelting  9.241147  9.019413  8.859360  8.574903  8.205131
# Smelting                  2.172934  2.121589  2.004034  1.788802  1.518632
# Casting                   0.240964  0.240730  0.240743  0.240043  0.238812
#
# Year                          2090      2100
# Stage
# Bauxite                   0.035797  0.035797
# Alumina                   2.434537  2.434537
# Anode                     0.156523  0.146693
# Electricity for smelting  7.167318  5.996951
# Smelting                  1.303399  1.185845
# Casting                   0.233843  0.227948

# %% [markdown]
# ## PRISMAL scenarios

# %%
#Evolution for every PRISMAL scenarios
region = 'GLO'
impact = 'GHG'
ms = 'msbl'

#Unit for y axis
unit=''
if impact=='GHG':
    unit='GHG [kg CO2 eq / kg Al]'
    
if impact=='HH':
    unit='HH [DALY / kg Al]'
    
if impact=='EQ':
    unit='EQ [PDF·m2·yr/m3 / kg Al]'

fig, (ax) = plt.subplots(1)
x = prismal_all.columns

#PRISMAL
y1 = prismal_all.loc(axis=0)['PRISMAL1', ms,:,region, impact].sum()
y1.plot(color='green', linewidth=4)
y2 = prismal_all.loc(axis=0)['PRISMAL2', ms,:,region, impact].sum()
y2.plot(color='blue', linewidth=4)
y3 = prismal_all.loc(axis=0)['PRISMAL3', ms,:,region, impact].sum()
y3.plot(color='red', linewidth=4)
y4 = prismal_all.loc(axis=0)['PRISMAL4', ms,:,region, impact].sum()
y4.plot(color='orange', linewidth=4)
y5 = prismal_all.loc(axis=0)['PRISMAL5', ms,:,region, impact].sum()
y5.plot(color='purple', linewidth=4)

#Axis and legend
plt.axis()
plt.xlabel('year')
plt.legend(['PRISMAL1','PRISMAL2', 'PRISMAL3', 'PRISMAL4', 'PRISMAL5'], title='PRISMAL Scenarios', loc=(3))
plt.ylabel(unit)
#plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
ax.set_ylim(ymin=0, ymax=21)
plt.axvline(x=2050, color='grey', ls=':', lw=1)
plt.rc('axes', labelsize= 15)

# %% [markdown]
# ## Regional results

# %%
#Regional dispersion
scenario = 'PRISMAL5'
impact = 'GHG'
ms = 'msbl'

#Unit for y axis
unit=''
if impact=='GHG':
    unit='GHG [kg CO2 eq / kg Al]'
    
if impact=='HH':
    unit='HH [DALY / kg Al]'
    
if impact=='EQ':
    unit='EQ [PDF·m2·yr/m3 / kg Al]'


x = prismal_all.columns

y1 = prismal_all.loc(axis=0)[scenario,ms,:,'Asia',impact].sum(axis=0)
y2 = prismal_all.loc(axis=0)[scenario,ms,:,'LAM',impact].sum(axis=0)
y3 = prismal_all.loc(axis=0)[scenario,ms,:,'OECD',impact].sum(axis=0)
y4 = prismal_all.loc(axis=0)[scenario,ms,:,'REF',impact].sum(axis=0)
y5 = prismal_all.loc(axis=0)[scenario,ms,:,'MAF',impact].sum(axis=0)

plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.plot(x, y4)
plt.plot(x, y5)

plt.xlabel('year')
plt.ylabel(unit)
plt.legend(['Asia','LAM','OECD','REF','MAF'],  fontsize=15, loc=(1.03, 0.25))
plt.title(scenario, size=15)
plt.ylim(ymin = 0)
print('Evolution of %s impacts for each regions in %s' % (impact, scenario))
plt.axvline(x=2050, color='grey', ls=':', lw=1)
plt.show()
# Out:
# Evolution of GHG impacts for each regions in PRISMAL5

# %% [markdown]
# ## Mitigation scenarios

# %%
#Evolution of results for different mitigations scenarios within a PRISMAL scenario
region = 'GLO'
impact = 'GHG'
scenario = 'PRISMAL2'

fig, (ax) = plt.subplots(1)

y19 = prismal_all.loc(axis=0)[scenario,'ms19',:,region,impact].sum()
y19.plot()
y26 = prismal_all.loc(axis=0)[scenario,'ms26',:,region,impact].sum()
y26.plot()
y34 = prismal_all.loc(axis=0)[scenario,'ms34',:,region,impact].sum()
y34.plot()
y45 = prismal_all.loc(axis=0)[scenario,'ms45',:,region,impact].sum()
y45.plot()
y60 = prismal_all.loc(axis=0)[scenario,'ms60',:,region,impact].sum()
y60.plot()
ybl = prismal_all.loc(axis=0)[scenario,'msbl',:,region,impact].sum()
ybl.plot()

plt.legend(['ms-19','ms-26','ms-34','ms-45','ms-60','ms-bl'], title='PRISMAL2', loc=(3))
plt.ylabel('GHG [kg CO2 eq. / kg al]')
ax.set_ylim(ymin=0)
plt.axvline(x=2050, color='grey', ls=':', lw=1)
